# %%
pip install azure-ai-projects azure-core azure-storage-blob
# Out:
# Collecting azure-ai-projects
#   Downloading azure_ai_projects-2.1.0-py3-none-any.whl.metadata (61 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.3/61.3 kB 2.3 MB/s eta 0:00:00
# Collecting azure-core
#   Downloading azure_core-1.39.0-py3-none-any.whl.metadata (48 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 48.6/48.6 kB 2.4 MB/s eta 0:00:00
# Collecting azure-storage-blob
#   Downloading azure_storage_blob-12.28.0-py3-none-any.whl.metadata (26 kB)
# Collecting isodate>=0.6.1 (from azure-ai-projects)
#   Downloading isodate-0.7.2-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: typing-extensions>=4.11 in /usr/local/lib/python3.12/dist-packages (from azure-ai-projects) (4.15.0)
# Collecting azure-identity>=1.15.0 (from azure-ai-projects)
#   Downloading azure_identity-1.25.3-py3-none-any.whl.metadata (91 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 91.7/91.7 kB 5.7 MB/s eta 0:00:00
# Requirement already satisfied: openai>=2.8.0 in /usr/local/lib/python3.12/dist-packages (from azure-ai-projects) (2.31.0)
# Requirement already satisfied: requests>=2.21.0 in /usr/local/lib/python3.12/dist-packages (from azure-core) (2.32.4)
# Requirement already satisfied: cryptography>=2.1.4 in /usr/local/lib/python3.12/dist-packages (from azure-storage-blob) (43.0.3)
# Collecting msal>=1.35.1 (from azure-identity>=1.15.0->azure-ai-projects)
#   Downloading msal-1.36.0-py3-none-any.whl.metadata (11 kB)
# Collecting msal-extensions>=1.2.0 (from azure-identity>=1.15.0->azure-ai-projects)
#   Downloading msal_extensions-1.3.1-py3-none-any.whl.metadata (7.8 kB)
# Requirement already satisfied: cffi>=1.12 in /usr/local/lib/python3.12/dist-packages (from cryptography>=2.1.4->azure-storage-blob) (2.0.0)
# Requirement already satisfied: anyio<5,>=3.5.0 in /usr/local/lib/python3.12/dist-packages (from openai>=2.8.0->azure-ai-projects) (4.13.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/local/lib/python3.12/dist-packages (from openai>=2.8.0->azure-ai-projects) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from openai>=2.8.0->azure-ai-projects) (0.28.1)
# Requirement already satisfied: jiter<1,>=0.10.0 in /usr/local/lib/python3.12/dist-packages (from openai>=2.8.0->azure-ai-projects) (0.14.0)
# Requirement already satisfied: pydantic<3,>=1.9.0 in /usr/local/lib/python3.12/dist-packages (from openai>=2.8.0->azure-ai-projects) (2.12.3)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.12/dist-packages (from openai>=2.8.0->azure-ai-projects) (1.3.1)
# Requirement already satisfied: tqdm>4 in /usr/local/lib/python3.12/dist-packages (from openai>=2.8.0->azure-ai-projects) (4.67.3)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.21.0->azure-core) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests>=2.21.0->azure-core) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests>=2.21.0->azure-core) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests>=2.21.0->azure-core) (2026.2.25)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.12/dist-packages (from cffi>=1.12->cryptography>=2.1.4->azure-storage-blob) (3.0)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->openai>=2.8.0->azure-ai-projects) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai>=2.8.0->azure-ai-projects) (0.16.0)
# Requirement already satisfied: PyJWT<3,>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from PyJWT[crypto]<3,>=1.0.0->msal>=1.35.1->azure-identity>=1.15.0->azure-ai-projects) (2.12.1)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic<3,>=1.9.0->openai>=2.8.0->azure-ai-projects) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.4 in /usr/local/lib/python3.12/dist-packages (from pydantic<3,>=1.9.0->openai>=2.8.0->azure-ai-projects) (2.41.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in /usr/local/lib/python3.12/dist-packages (from pydantic<3,>=1.9.0->openai>=2.8.0->azure-ai-projects) (0.4.2)
# Downloading azure_ai_projects-2.1.0-py3-none-any.whl (274 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 274.3/274.3 kB 15.2 MB/s eta 0:00:00
# Downloading azure_core-1.39.0-py3-none-any.whl (218 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 218.3/218.3 kB 11.3 MB/s eta 0:00:00
# Downloading azure_storage_blob-12.28.0-py3-none-any.whl (431 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 431.5/431.5 kB 16.2 MB/s eta 0:00:00
# Downloading azure_identity-1.25.3-py3-none-any.whl (192 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 192.1/192.1 kB 9.0 MB/s eta 0:00:00
# Downloading isodate-0.7.2-py3-none-any.whl (22 kB)
# Downloading msal-1.36.0-py3-none-any.whl (121 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 121.5/121.5 kB 7.1 MB/s eta 0:00:00
# Downloading msal_extensions-1.3.1-py3-none-any.whl (20 kB)
# Installing collected packages: isodate, azure-core, azure-storage-blob, msal, msal-extensions, azure-identity, azure-ai-projects
# Successfully installed azure-ai-projects-2.1.0 azure-core-1.39.0 azure-identity-1.25.3 azure-storage-blob-12.28.0 isodate-0.7.2 msal-1.36.0 msal-extensions-1.3.1

# %%
pip install --upgrade openai azure-ai-projects azure-identity
# Out:
# Requirement already satisfied: openai in /usr/local/lib/python3.12/dist-packages (2.31.0)
# Collecting openai
#   Downloading openai-2.32.0-py3-none-any.whl.metadata (31 kB)
# Requirement already satisfied: azure-ai-projects in /usr/local/lib/python3.12/dist-packages (2.1.0)
# Requirement already satisfied: azure-identity in /usr/local/lib/python3.12/dist-packages (1.25.3)
# Requirement already satisfied: anyio<5,>=3.5.0 in /usr/local/lib/python3.12/dist-packages (from openai) (4.13.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/local/lib/python3.12/dist-packages (from openai) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from openai) (0.28.1)
# Requirement already satisfied: jiter<1,>=0.10.0 in /usr/local/lib/python3.12/dist-packages (from openai) (0.14.0)
# Requirement already satisfied: pydantic<3,>=1.9.0 in /usr/local/lib/python3.12/dist-packages (from openai) (2.12.3)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.12/dist-packages (from openai) (1.3.1)
# Requirement already satisfied: tqdm>4 in /usr/local/lib/python3.12/dist-packages (from openai) (4.67.3)
# Requirement already satisfied: typing-extensions<5,>=4.11 in /usr/local/lib/python3.12/dist-packages (from openai) (4.15.0)
# Requirement already satisfied: isodate>=0.6.1 in /usr/local/lib/python3.12/dist-packages (from azure-ai-projects) (0.7.2)
# Requirement already satisfied: azure-core>=1.37.0 in /usr/local/lib/python3.12/dist-packages (from azure-ai-projects) (1.39.0)
# Requirement already satisfied: azure-storage-blob>=12.15.0 in /usr/local/lib/python3.12/dist-packages (from azure-ai-projects) (12.28.0)
# Requirement already satisfied: cryptography>=2.5 in /usr/local/lib/python3.12/dist-packages (from azure-identity) (43.0.3)
# Requirement already satisfied: msal>=1.35.1 in /usr/local/lib/python3.12/dist-packages (from azure-identity) (1.36.0)
# Requirement already satisfied: msal-extensions>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from azure-identity) (1.3.1)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.12/dist-packages (from anyio<5,>=3.5.0->openai) (3.11)
# Requirement already satisfied: requests>=2.21.0 in /usr/local/lib/python3.12/dist-packages (from azure-core>=1.37.0->azure-ai-projects) (2.32.4)
# Requirement already satisfied: cffi>=1.12 in /usr/local/lib/python3.12/dist-packages (from cryptography>=2.5->azure-identity) (2.0.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->openai) (2026.2.25)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->openai) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai) (0.16.0)
# Requirement already satisfied: PyJWT<3,>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from PyJWT[crypto]<3,>=1.0.0->msal>=1.35.1->azure-identity) (2.12.1)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic<3,>=1.9.0->openai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.4 in /usr/local/lib/python3.12/dist-packages (from pydantic<3,>=1.9.0->openai) (2.41.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in /usr/local/lib/python3.12/dist-packages (from pydantic<3,>=1.9.0->openai) (0.4.2)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.12/dist-packages (from cffi>=1.12->cryptography>=2.5->azure-identity) (3.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.21.0->azure-core>=1.37.0->azure-ai-projects) (3.4.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests>=2.21.0->azure-core>=1.37.0->azure-ai-projects) (2.5.0)
# Downloading openai-2.32.0-py3-none-any.whl (1.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 24.8 MB/s eta 0:00:00
# Installing collected packages: openai
#   Attempting uninstall: openai
#     Found existing installation: openai 2.31.0
#     Uninstalling openai-2.31.0:
#       Successfully uninstalled openai-2.31.0
# Successfully installed openai-2.32.0

# %%
from openai import OpenAI
import os
from google.colab import userdata

# Retrieve the secret key from Google Colab
api_key = userdata.get("New_Open_AI")

client = OpenAI(
    api_key=api_key,  # Picks up the secret key from Colab environment
    base_url="https://bolob435.openai.azure.com/openai/v1"
)

# Note: api_version is usually NOT required when using this path in 2026

# %%
# 1. Define the input data
# In a real scenario, you can load this from a .txt or .json file
resume_data = """
RICHARD SANCHEZ
Education: Master of Business Management (2029-2030)
Work: Marketing Manager at Borcelle Studio (2030-Present)
Skills: Project Management, PR, Leadership...
"""

# 2. Use the Responses API for structured extraction
# Use the structured input pattern for GPT-4.1
# Updated call with 2026-compliant type naming
try:
    response = client.responses.create(
        model="gpt-4.1",
        input=[
            {
                "role": "user",
                "content": [
                    {
                        "type": "input_text",  # Changed from 'text'
                        "text": "Extract the following details into a JSON object: Name, Education, Latest Job, and Top 3 Skills. Return ONLY valid JSON."
                    },
                    {
                        "type": "input_text",  # Changed from 'text'
                        "text": f"RESUME SOURCE:\n{resume_data}"
                    }
                ]
            }
        ]
    )

    print("--- EXTRACTED DATA ---")
    print(response.output[0].content)

except Exception as e:
    print(f"Extraction Error: {e}")
# Out:
# --- EXTRACTED DATA ---
# [ResponseOutputText(annotations=[], text='{\n  "Name": "Richard Sanchez",\n  "Education": "Master of Business Management (2029-2030)",\n  "Latest Job": "Marketing Manager at Borcelle Studio (2030-Present)",\n  "Top 3 Skills": ["Project Management", "PR", "Leadership"]\n}', type='output_text', logprobs=[])]

# %%
import json

try:
    # 1. Get the first item in the content list
    # 2. Access the 'text' attribute of that item
    output_text_item = response.output[0].content[0]

    # In some SDK versions, it's a dict; in others, it's an object.
    # This handles both:
    if isinstance(output_text_item, dict):
        raw_json_string = output_text_item.get("text", "")
    else:
        raw_json_string = output_text_item.text

    # Now parse the actual string
    extracted_data = json.loads(raw_json_string)

    print("--- SUCCESS: DATA PARSED ---")
    print(json.dumps(extracted_data, indent=2))

except Exception as e:
    print(f"Parsing Error: {e}")
    # Troubleshooting: print the type to see what exactly was returned
    print(f"Actual content type: {type(response.output[0].content[0])}")
# Out:
# --- SUCCESS: DATA PARSED ---
# {
#   "Name": "Richard Sanchez",
#   "Education": "Master of Business Management (2029-2030)",
#   "Latest Job": "Marketing Manager at Borcelle Studio (2030-Present)",
#   "Top 3 Skills": [
#     "Project Management",
#     "PR",
#     "Leadership"
#   ]
# }

# %%
from azure.storage.blob import BlobServiceClient

# ✅ Correct connection string
AZURE_STORAGE_CONNECTION_STRING = "DefaultEndpointsProtocol=https;AccountName=mrinalstorage;AccountKey=PHtgo0Sd+nYgLm4WXvHBp+rv7laJJsvg6Y3EXfO4ZEYuNDlffd2RdauObtclMrVVbxHpF6o8QmKN+ASt0qj8PA==;EndpointSuffix=core.windows.net"

blob_service_client = BlobServiceClient.from_connection_string(
    AZURE_STORAGE_CONNECTION_STRING
)

container_name = "output-container"

blob_client = blob_service_client.get_blob_client(
    container=container_name,
    blob="result.txt"
)

blob_client.upload_blob("Test upload", overwrite=True)

print("✅ Upload successful")
# Out:
# ✅ Upload successful

# %%
import datetime

file_name = f"resume_{datetime.datetime.now().strftime('%Y%m%d_%H%M%S')}.txt"

# %%
blob_client = blob_service_client.get_blob_client(
    container="output-container",
    blob=file_name
)

blob_client.upload_blob(response.output_text, overwrite=True)
# Out:
# {'etag': '"0x8DE9F70EA288F61"',
#  'last_modified': datetime.datetime(2026, 4, 21, 6, 40, 44, tzinfo=datetime.timezone.utc),
#  'content_md5': bytearray(b'\xdb\xe3g\xe1$0\xd2G\xd7k\xff\x97\xbd\xe3\xdb`'),
#  'client_request_id': '05ea7fcc-3d4d-11f1-9224-0242ac1c000c',
#  'request_id': 'afceca85-501e-009b-3059-d14a62000000',
#  'version': '2026-02-06',
#  'version_id': None,
#  'date': datetime.datetime(2026, 4, 21, 6, 40, 44, tzinfo=datetime.timezone.utc),
#  'request_server_encrypted': True,
#  'encryption_key_sha256': None,
#  'encryption_scope': None,
#  'structured_body': None}

# %%
print(f"✅ Stored as: {file_name}")
# Out:
# ✅ Stored as: resume_20260421_064043.txt
